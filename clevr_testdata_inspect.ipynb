# %%
import numpy as np
import h5py
import os 

data_folder = "/data/clevr_change_pre_sc"
base_filename = "CLEVR_CHANGE_9_cap_per_img_pair_1_min_word_freq"
split_name = "TEST_SC"
file_name = split_name + '_STORE_' + base_filename + '.hdf5'

data = h5py.File(os.path.join(data_folder, file_name), 'r')

# %%
samples = data["image_pairs"]

# %%
samples.shape
# Out:
# (3985, 921600)

# %%
sample = samples[0]

# %%
sample.shape
# Out:
# (921600,)

# %%
from matplotlib import pyplot as plt

iml = 3 * 320 * 480 
imb = sample[:iml]
ima = sample[iml:iml*2]

# %%
print(imb.shape, ima.shape)
# Out:
# (460800,) (460800,)

# %%
plt.imshow(imb.reshape(3,320,480).transpose(1,2,0))

# %%
plt.imshow(ima.reshape(3,320,480).transpose(1,2,0))

# %%
import json
with open(os.path.join(data_folder, split_name + '_STORE_' + base_filename + '.json')) as f:
    captions = json.load(f)

# %%
# [58.,  1., 10.,  3.,  6.,  7., 36., 59., 
len(captions[0])
# Out:
# 9
